# %% [markdown]
# ---
#
# <center>
#
# <h1><b>Final Project</b></h1>
# <h3>Universidad Carlos III de Madrid · Web Analytics</h3>
#
# <p><em>Development of a robust web scraper to understand the job market in Madrid.</em></p>
#
#
#
# </center>
#
# <p>Group 3</p>
#
# - Sergio Madrid (100496657@alumnos.uc3m.es)
# - Adeline Poncet (100497721@alumnos.uc3m.es)
# - Blanca Sánchez (100496636@alumnos.uc3m.es)
# - Enica King (100496551@alumnos.uc3m.es)
#
# ---

# %% [markdown]
# # 1 Web Scraping
