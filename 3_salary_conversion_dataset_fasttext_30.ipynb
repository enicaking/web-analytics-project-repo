# %% [markdown]
# #### Purpose of this notebook

# %% [markdown]
# This notebook contains the conversion of salary data to \$/year and store the corresponding dataset. It uses the dataset generated with vectors of dim 30 as embedding representation of the 'description' field.

# %% [markdown]
# #### Setup environment and libraries

# %%
import os

# %%
# For Colab environment
#from google.colab import drive
#drive.mount('/content/drive')

# %%
# Change directory
# folder_path = "/content/drive/My Drive/Web Analytics/Final project scraped data/"
folder_path =r"C:\Users\adeli\Documents 4-Q1\Web Analytics\Final Project GitHub\web-analytics-project-repo"
os.chdir(folder_path)

# %%
# Check
current_dir = os.getcwd()
print(current_dir)
# Out:
# C:\Users\adeli\Documents 4-Q1\Web Analytics\Final Project GitHub\web-analytics-project-repo

# %%
# Libraries to use
# Standard libraries
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", None)   # no column truncation
pd.set_option("display.max_rows", None)      # no row truncation
pd.set_option("display.width", None)         # no line-wrapping
pd.set_option("display.max_colwidth", None)
import numpy as np
import ast
import matplotlib.pyplot as plt
import seaborn as sns
# Specific libraries
import json
from pathlib import Path
import re

# %% [markdown]
# #### Transform dataset: Salary conversion to $/hour

# %% [markdown]
# In this notebook, as we have already established that the regression in \$/hour fares better than in \$/year (better performance), we perform only the conversion of salaries to \$/hour, and using the embeddings dim 30, to check whether they allow to a better regression performance than embeddings dim 300.

# %%
# To reload after volunteer elimination and with embeddings dim 30 in description
file_path= "C:/Users/adeli/Documents 4-Q1/Web Analytics/Final Project GitHub/web-analytics-project-repo/Processed data/"
file_name= "linkedin_description_30_vectors.csv"
df=pd.read_csv(file_path + file_name)
print(f"Data has been recovered from csv file.")
# Out:
# Data has been recovered from csv file.

# %%
print("\n====== Check NAs ======")
print(df.isna().sum().to_frame(name="NA_Counts"))
# Out:
# ====== Check NAs ======
#                    NA_Counts
# offer_id                   0
# title                      0
# company_name               0
# city                     408
# state_code                 0
# seniority_level            0
# job_type                   0
# job_function               5
# industry                   1
# description                0
# salary_min              3673
# salary_max              3673
# salary_unit             3676
# salary                  3673
# searched_position          0
# searched_location          0
# applications               0
# nltk_lemmas                0

# %%
from importlib import reload
import utilities
reload(utilities)
# Out:
# <module 'utilities' from 'C:\\Users\\adeli\\Documents 4-Q1\\Web Analytics\\Final Project GitHub\\web-analytics-project-repo\\utilities.py'>

# %%
from utilities import salary_conversion

# %%
# Need to map each job_type to hours_a_week, modify if needed
hours_map = {
    "Full-time": 40,
    "Part-time": 20,
    "Internship": 40,
    "Contract": 40,
    "Temporary": 40,
    "Other": 40,
}

# Create hours_a_week column
df["hours_a_week"] = df["job_type"].map(hours_map)

# %%
df.columns
# Out:
# Index(['offer_id', 'title', 'company_name', 'city', 'state_code',
#        'seniority_level', 'job_type', 'job_function', 'industry',
#        'description', 'salary_min', 'salary_max', 'salary_unit', 'salary',
#        'searched_position', 'searched_location', 'applications', 'nltk_lemmas',
#        'hours_a_week'],
#       dtype='object')

# %%
# Check that now all entries with salary_min not NaN have salary_unit not NaN
mask_check = df["salary_min"].notna() & df["salary_unit"].isna()
num_check = mask_check.sum()
print(f"Number of entries with salary_min not NaN and salary_unit NaN: {num_check}")
# Out:
# Number of entries with salary_min not NaN and salary_unit NaN: 3

# %%
df[mask_check].drop(columns=["description", "nltk_lemmas"]).head(5)
# Out:
#       offer_id                title                     company_name  \
# 115        115    Software Engineer  Scientific Research Corporation
# 1348      1350  Systems Engineer IV  Scientific Research Corporation
# 6892      6894  Sr Network Engineer  Scientific Research Corporation
#
#            city state_code   seniority_level   job_type  \
# 115   San Diego         CA  Mid-Senior level  Full-time
# 1348  San Diego         CA  Mid-Senior level  Full-time
# 6892  San Diego         CA  Mid-Senior level  Full-time
#
#                                 job_function              industry  \
# 115   Information Technology and Engineering  Engineering Services
# 1348  Information Technology and Engineering  Engineering Services
# 6892  Information Technology and Engineering  Engineering Services
#
#       salary_min  salary_max salary_unit  \
# 115     127650.0    160000.0         NaN
# 1348    146800.0    244650.0         NaN
# 6892    111100.0    185100.0         NaN
#
#                                      salary  searched_position  \
# 115   $127,650.00/daily - $160,000.00/daily  Software Engineer
# 1348  $146,800.00/daily - $244,650.00/daily   Systems Engineer
# 6892  $111,100.00/daily - $185,100.00/daily   Network Engineer
#
#      searched_location         applications  hours_a_week
# 115          San Diego        54 applicants            40
# 1348         San Diego        26 applicants            40
# 6892     National City  Over 200 applicants            40

# %%
# Issue to correct: some entries have salary_unit as NaN, need to correct them.
# After examination, their unit is 'year', so we correct them.
df.loc[df["salary_unit"].isna(), "salary_unit"] = "year"

# %%
df.loc[mask_check, "salary_unit"] = "hour"

# %%
# Check again
mask_check = df["salary_min"].notna() & df["salary_unit"].isna()
num_check = mask_check.sum()
print(f"Number of entries with salary_min not NaN and salary_unit NaN: {num_check}")
# Out:
# Number of entries with salary_min not NaN and salary_unit NaN: 0

# %%
# Another issue detected: some entries have salary_unit as hour, but salary_max> 1000
mask_140= (df["salary_unit"] == "hour") & (df["salary_max"] > 140)
df_hour_over_140 = df[mask_140]
print(len(df_hour_over_140))
df_hour_over_140.drop(columns=["description", "nltk_lemmas"])
# Out:
# 11
#        offer_id                                   title  \
# 115         115                       Software Engineer
# 1348       1350                     Systems Engineer IV
# 1678       1680                Senior Firmware Engineer
# 3218       3220  Field Service Engineer- Sacramento, CA
# 3302       3304       Ultrasound Field Service Engineer
# 6205       6207                  Electrical Engineer II
# 6454       6456                  Mechanical Engineer II
# 6892       6894                     Sr Network Engineer
# 9497       9502                   Data Engineer/Analyst
# 10045     10050                        Quality Engineer
# 10237     10243                        Quality Engineer
#
#                            company_name             city state_code  \
# 115     Scientific Research Corporation        San Diego         CA
# 1348    Scientific Research Corporation        San Diego         CA
# 1678                         Kforce Inc          Cypress         CA
# 3218            Avante Health Solutions       Sacramento         CA
# 3302            Avante Health Solutions      Los Angeles         CA
# 6205                      CROWNMAZE LTD  El Dorado Hills         CA
# 6454                      CROWNMAZE LTD  El Dorado Hills         CA
# 6892    Scientific Research Corporation        San Diego         CA
# 9497   Advanced Structural Technologies           Oxnard         CA
# 10045                             Jobot         Pasadena         CA
# 10237                             Jobot         Pasadena         CA
#
#         seniority_level   job_type                            job_function  \
# 115    Mid-Senior level  Full-time  Information Technology and Engineering
# 1348   Mid-Senior level  Full-time  Information Technology and Engineering
# 1678          Associate   Contract  Engineering and Information Technology
# 3218   Mid-Senior level  Full-time                  Information Technology
# 3302        Entry level  Full-time                  Information Technology
# 6205   Mid-Senior level  Full-time  Engineering and Information Technology
# 6454   Mid-Senior level  Full-time  Engineering and Information Technology
# 6892   Mid-Senior level  Full-time  Information Technology and Engineering
# 9497          Associate  Full-time                                 Analyst
# 10045    Not Applicable  Full-time                       Quality Assurance
# 10237    Not Applicable  Full-time                       Quality Assurance
#
#                                                      industry  salary_min  \
# 115                                      Engineering Services    127650.0
# 1348                                     Engineering Services    146800.0
# 1678                            IT Services and IT Consulting    124000.0
# 3218                          Medical Equipment Manufacturing    150000.0
# 3302                          Medical Equipment Manufacturing     75000.0
# 6205                                              Hospitality     85891.0
# 6454                                              Hospitality     88969.0
# 6892                                     Engineering Services    111100.0
# 9497                                            Manufacturing     80000.0
# 10045  IT Services and IT Consulting and Software Development    110000.0
# 10237  IT Services and IT Consulting and Software Development    110000.0
#
#        salary_max salary_unit                                 salary  \
# 115      160000.0        hour  $127,650.00/daily - $160,000.00/daily
# 1348     244650.0        hour  $146,800.00/daily - $244,650.00/daily
# 1678     140000.0        hour        $124,000.00/hr - $140,000.00/hr
# 3218     180000.0        hour        $150,000.00/hr - $180,000.00/hr
# 3302      95000.0        hour          $75,000.00/hr - $95,000.00/hr
# 6205     119195.0        hour         $85,891.00/hr - $119,195.00/hr
# 6454     107091.0        hour         $88,969.00/hr - $107,091.00/hr
# 6892     185100.0        hour  $111,100.00/daily - $185,100.00/daily
# 9497     105000.0        hour         $80,000.00/hr - $105,000.00/hr
# 10045    150000.0        hour        $110,000.00/hr - $150,000.00/hr
# 10237    150000.0        hour        $110,000.00/hr - $150,000.00/hr
#
#                searched_position searched_location  \
# 115            Software Engineer         San Diego
# 1348            Systems Engineer         San Diego
# 1678   Embedded Systems Engineer           Anaheim
# 3218         Biomedical Engineer         Elk Grove
# 3302         Biomedical Engineer           Anaheim
# 6205           Hardware Engineer         Roseville
# 6454         Mechanical Engineer         Roseville
# 6892            Network Engineer     National City
# 9497               Data Engineer           Ventura
# 10045        Industrial Engineer    West Hollywood
# 10237        Industrial Engineer            Pomona
#
#                            applications  hours_a_week
# 115                       54 applicants            40
# 1348                      26 applicants            40
# 1678   Be among the first 25 applicants            40
# 3218   Be among the first 25 applicants            40
# 3302   Be among the first 25 applicants            40
# 6205   Be among the first 25 applicants            40
# 6454   Be among the first 25 applicants            40
# 6892                Over 200 applicants            40
# 9497                Over 200 applicants            40
# 10045  Be among the first 25 applicants            40
# 10237  Be among the first 25 applicants            40

# %%
# Update salary_unit to 'year' for those rows
df.loc[mask_140, "salary_unit"] = "year"

# %%
# Check again
mask_140= (df["salary_unit"] == "hour") & (df["salary_max"] > 140)
df_hour_over_140 = df[mask_140]
print(len(df_hour_over_140))
# Out:
# 0

# %%
# Issue 3 to correct: some entries have salaries in unit 'year' that should be, after
# examination, in 'hour' unit. We correct them.
# Establish a threshold
threshold = 250

mask_min= (df["salary_unit"] == "year") & (df["salary_max"] < threshold)
df_hour_under_thr = df[mask_min]
print(len(df_hour_under_thr))
df_hour_under_thr.drop(columns=["description", "nltk_lemmas"])
# Out:
# 31
#        offer_id  \
# 793         795
# 1140       1142
# 1246       1248
# 1829       1831
# 2878       2880
# 3027       3029
# 3849       3851
# 4207       4209
# 4296       4298
# 4319       4321
# 4358       4360
# 4588       4590
# 4591       4593
# 4752       4754
# 5119       5121
# 5629       5631
# 6125       6127
# 6675       6677
# 7125       7127
# 7757       7759
# 7838       7840
# 8719       8722
# 8910       8915
# 9265       9270
# 9277       9282
# 9424       9429
# 9777       9782
# 9904       9909
# 10317     10323
# 10402     10408
# 10473     10479
#
#                                                                               title  \
# 793                                                  Python Developer (Azure cloud)
# 1140                                                    Azure Devops Cloud engineer
# 1246                                    Information Security Engineer (CISSP, CISM)
# 1829                                                        Control System Engineer
# 2878                                                        Director of Engineering
# 3027                                            MSAT Process Engineer II – Upstream
# 3849                                                Frontend Engineer (Anime Games)
# 4207                                                    Automation Control Engineer
# 4296                                                             Senior QA Engineer
# 4319                                Manufacturing Test Automation Engineer (Python)
# 4358           Senior Python Developer – Production Test Automation (Manufacturing)
# 4588                                2026 Summer Internship - Electrical Engineering
# 4591                                2026 Summer Internship - Electrical Engineering
# 4752                                                               Product Engineer
# 5119                                      Environmental Specialist/Field Technician
# 5629                                                              Network Architect
# 6125                                                AI & Robotics Support Associate
# 6675                                       Staff Process Engineer (Wafer Finishing)
# 7125                                                        R&D Mechanical Engineer
# 7757                       Sr. Electrical Test Engineer/ Electrical Test Technician
# 7838                                        Sr. Electrical Test Technician Engineer
# 8719                                                            Electrical Engineer
# 8910                                           2026 Summer Civil Engineer Assistant
# 9265   2026 Summer Internship - Data Analytics/Data Science/Applied Math/Statistics
# 9277                                                           Planning, Specialist
# 9424                                                              Software Engineer
# 9777                                                       Hardware Design Engineer
# 9904                                                      Supplier Quality Engineer
# 10317                          2026 Summer Internship - Data Analytics/Data Science
# 10402                                      2026 Summer Internship - All Engineering
# 10473                               2026 Summer Internship - Electrical Engineering
#
#                            company_name           city state_code  \
# 793              DivIHN Integration Inc      San Diego         CA
# 1140             DivIHN Integration Inc      San Diego         CA
# 1246                         TechSource   San Fernando         CA
# 1829                     Insight Global       El Cajon         CA
# 2878                            DeSanti            NaN        los
# 3027       Polaris Pharmaceuticals Inc.      Vacaville         CA
# 3849                         Spellbrush  San Francisco         CA
# 4207               Zion Talent Partners        Modesto         CA
# 4296                         Hyperbound  San Francisco         CA
# 4319               Red Oak Technologies  San Francisco         CA
# 4358               Red Oak Technologies  San Francisco         CA
# 4588   Southern California Edison (SCE)       Redlands         CA
# 4591   Southern California Edison (SCE)        Fontana         CA
# 4752                              Govly  San Francisco         CA
# 5119                                FCS        Alameda         CA
# 5629                     Insight Global      Santa Ana         CA
# 6125                               UNIS  Orange County         CA
# 6675              Halo Industries, Inc.    Santa Clara         CA
# 7125             DivIHN Integration Inc      San Diego         CA
# 7757            Accord Technologies Inc         Irvine         CA
# 7838            Accord Technologies Inc         Irvine         CA
# 8719                             SCITON      Palo Alto         CA
# 8910                      BKF Engineers   Redwood City         CA
# 9265   Southern California Edison (SCE)    Victorville         CA
# 9277   Southern California Edison (SCE)    Victorville         CA
# 9424                              Curri        Ventura         CA
# 9777                   Innova Solutions    Santa Clara         CA
# 9904            Accord Technologies Inc      Camarillo         CA
# 10317  Southern California Edison (SCE)      Lancaster         CA
# 10402  Southern California Edison (SCE)       Palmdale         CA
# 10473  Southern California Edison (SCE)         Pomona         CA
#
#         seniority_level   job_type  \
# 793    Mid-Senior level   Contract
# 1140     Not Applicable   Contract
# 1246   Mid-Senior level  Full-time
# 1829          Associate  Full-time
# 2878           Director  Full-time
# 3027          Associate  Full-time
# 3849        Entry level  Full-time
# 4207   Mid-Senior level  Full-time
# 4296   Mid-Senior level  Full-time
# 4319   Mid-Senior level  Full-time
# 4358   Mid-Senior level  Full-time
# 4588     Not Applicable  Full-time
# 4591     Not Applicable  Full-time
# 4752        Entry level  Full-time
# 5119        Entry level  Full-time
# 5629   Mid-Senior level   Contract
# 6125         Internship  Full-time
# 6675   Mid-Senior level  Full-time
# 7125   Mid-Senior level   Contract
# 7757   Mid-Senior level  Full-time
# 7838   Mid-Senior level  Full-time
# 8719   Mid-Senior level  Part-time
# 8910         Internship  Temporary
# 9265     Not Applicable  Full-time
# 9277     Not Applicable  Full-time
# 9424   Mid-Senior level  Full-time
# 9777   Mid-Senior level  Full-time
# 9904   Mid-Senior level  Full-time
# 10317    Not Applicable  Full-time
# 10402    Not Applicable  Full-time
# 10473    Not Applicable  Full-time
#
#                                                 job_function  \
# 793                                   Information Technology
# 1140                                  Information Technology
# 1246                                    Health Care Provider
# 1829                                  Engineering and Design
# 2878                                             Engineering
# 3027                                           Manufacturing
# 3849                  Engineering and Information Technology
# 4207                                           Manufacturing
# 4296                  Engineering and Information Technology
# 4319   Information Technology, Manufacturing, and Management
# 4358                Information Technology and Manufacturing
# 4588                                                   Other
# 4591                                                   Other
# 4752                  Engineering and Information Technology
# 5119                            Management and Manufacturing
# 5629                                  Information Technology
# 6125                                                   Other
# 6675                                             Engineering
# 7125                                  Information Technology
# 7757                                       Quality Assurance
# 7838                                       Quality Assurance
# 8719                  Engineering and Information Technology
# 8910                  Engineering and Information Technology
# 9265                                                   Other
# 9277                                                   Other
# 9424                  Engineering and Information Technology
# 9777                       Design and Information Technology
# 9904                                       Quality Assurance
# 10317                                                  Other
# 10402                                                  Other
# 10473                                                  Other
#
#                                                                                                             industry  \
# 793                                                 Pharmaceutical Manufacturing and Medical Equipment Manufacturing
# 1140                                                Pharmaceutical Manufacturing and Medical Equipment Manufacturing
# 1246                               Hospitals and Health Care, Medical Equipment Manufacturing, and Medical Practices
# 1829                                             Pharmaceutical Manufacturing and Automation Machinery Manufacturing
# 2878                                           Civil Engineering, Rail Transportation, and Government Administration
# 3027                                                         Biotechnology Research and Pharmaceutical Manufacturing
# 3849                                                                                                  Computer Games
# 4207   Food and Beverage Manufacturing, Fruit and Vegetable Preserves Manufacturing, and Dairy Product Manufacturing
# 4296                                                                                            Software Development
# 4319                                                           Appliances, Electrical, and Electronics Manufacturing
# 4358                                         Appliances, Electrical, and Electronics Manufacturing and Manufacturing
# 4588                                                                                       Oil and Gas and Utilities
# 4591                                                                                       Oil and Gas and Utilities
# 4752                                                                                            Software Development
# 5119                                      Non-profit Organizations, Hospitals and Health Care, and Medical Practices
# 5629                                                                            IT System Operations and Maintenance
# 6125                                                                                            Truck Transportation
# 6675                                                                                   IT Services and IT Consulting
# 7125                                                Pharmaceutical Manufacturing and Medical Equipment Manufacturing
# 7757                                                                               Information Technology & Services
# 7838                                                                               Information Technology & Services
# 8719                                                                                 Medical Equipment Manufacturing
# 8910                                                                                   IT Services and IT Consulting
# 9265                                                                                       Oil and Gas and Utilities
# 9277                                                                                       Oil and Gas and Utilities
# 9424                                                                            Technology, Information and Internet
# 9777                                                                                       Electric Power Generation
# 9904                                                                               Information Technology & Services
# 10317                                                                                      Oil and Gas and Utilities
# 10402                                                                                      Oil and Gas and Utilities
# 10473                                                                                      Oil and Gas and Utilities
#
#        salary_min  salary_max salary_unit                   salary  \
# 793         60.00       65.00        year    $60.00/yr - $65.00/yr
# 1140        55.00       58.00        year    $55.00/yr - $58.00/yr
# 1246       140.00      150.00        year  $140.00/yr - $150.00/yr
# 1829        55.00       60.00        year    $55.00/yr - $60.00/yr
# 2878       127.00      190.00        year  $127.00/yr - $190.00/yr
# 3027       110.00      120.00        year  $110.00/yr - $120.00/yr
# 3849        60.00      180.00        year   $60.00/yr - $180.00/yr
# 4207        40.00       48.50        year    $40.00/yr - $48.50/yr
# 4296       120.00      160.00        year  $120.00/yr - $160.00/yr
# 4319       165.00      175.00        year  $165.00/yr - $175.00/yr
# 4358       165.00      175.00        year  $165.00/yr - $175.00/yr
# 4588        17.00       28.00        year    $17.00/yr - $28.00/yr
# 4591        17.00       28.00        year    $17.00/yr - $28.00/yr
# 4752       150.00      240.00        year  $150.00/yr - $240.00/yr
# 5119        23.00       32.00        year    $23.00/yr - $32.00/yr
# 5629        75.00       78.00        year    $75.00/yr - $78.00/yr
# 6125        25.00       26.00        year    $25.00/yr - $26.00/yr
# 6675       155.00      170.00        year  $155.00/yr - $170.00/yr
# 7125        50.00       54.00        year    $50.00/yr - $54.00/yr
# 7757        60.00       60.00        year    $60.00/yr - $60.00/yr
# 7838        60.00       65.00        year    $60.00/yr - $65.00/yr
# 8719       125.00      162.00        year  $125.00/yr - $162.00/yr
# 8910        24.00       32.00        year    $24.00/yr - $32.00/yr
# 9265        17.00       28.00        year    $17.00/yr - $28.00/yr
# 9277        41.92       62.84        year    $41.92/yr - $62.84/yr
# 9424       168.00      180.00        year  $168.00/yr - $180.00/yr
# 9777       120.00      130.00        year  $120.00/yr - $130.00/yr
# 9904        50.00       50.00        year    $50.00/yr - $50.00/yr
# 10317       17.00       28.00        year    $17.00/yr - $28.00/yr
# 10402       17.00       28.00        year    $17.00/yr - $28.00/yr
# 10473       17.00       28.00        year    $17.00/yr - $28.00/yr
#
#               searched_position searched_location  \
# 793             DevOps Engineer         San Diego
# 1140             Cloud Engineer         San Diego
# 1246          Security Engineer       Los Angeles
# 1829        Automation Engineer         San Diego
# 2878             Civil Engineer           Anaheim
# 3027        Industrial Engineer              Napa
# 3849          Frontend Engineer     San Francisco
# 4207        Automation Engineer           Lathrop
# 4296                QA Engineer     San Francisco
# 4319                QA Engineer     San Francisco
# 4358   Test Automation Engineer     San Francisco
# 4588        Electrical Engineer        Loma Linda
# 4591        Electrical Engineer        Loma Linda
# 4752        Mechanical Engineer     San Francisco
# 5119     Environmental Engineer     San Francisco
# 5629           Network Engineer           Norwalk
# 6125          Robotics Engineer           Norwalk
# 6675          Chemical Engineer        Menlo Park
# 7125        Mechanical Engineer     National City
# 7757        Automation Engineer     Orange County
# 7838          Hardware Engineer     Orange County
# 8719        Electrical Engineer          Milpitas
# 8910     Environmental Engineer          Milpitas
# 9265              Data Engineer      Apple Valley
# 9277        Electrical Engineer      Apple Valley
# 9424          Software Engineer           Ventura
# 9777          Hardware Engineer       Santa Clara
# 9904        Mechanical Engineer           Ventura
# 10317             Data Engineer         Lancaster
# 10402       Electrical Engineer         Lancaster
# 10473       Electrical Engineer            Colton
#
#                            applications  hours_a_week
# 793                      143 applicants            40
# 1140   Be among the first 25 applicants            40
# 1246                      89 applicants            40
# 1829   Be among the first 25 applicants            40
# 2878   Be among the first 25 applicants            40
# 3027                Over 200 applicants            40
# 3849                Over 200 applicants            40
# 4207                      26 applicants            40
# 4296                     113 applicants            40
# 4319                      29 applicants            40
# 4358   Be among the first 25 applicants            40
# 4588   Be among the first 25 applicants            40
# 4591                      28 applicants            40
# 4752                      60 applicants            40
# 5119                      49 applicants            40
# 5629                     143 applicants            40
# 6125                      50 applicants            40
# 6675   Be among the first 25 applicants            40
# 7125                     200 applicants            40
# 7757   Be among the first 25 applicants            40
# 7838   Be among the first 25 applicants            40
# 8719   Be among the first 25 applicants            20
# 8910   Be among the first 25 applicants            40
# 9265                      47 applicants            40
# 9277   Be among the first 25 applicants            40
# 9424                      69 applicants            40
# 9777                      32 applicants            40
# 9904   Be among the first 25 applicants            40
# 10317                     91 applicants            40
# 10402                     87 applicants            40
# 10473                     73 applicants            40

# %%
# Update salary_unit to 'hour' for those rows
df.loc[mask_min, "salary_unit"] = "hour"

# %%
# Check again
mask_min= (df["salary_unit"] == "year") & (df["salary_max"] < threshold)
df_hour_under_thr = df[mask_min]
print(len(df_hour_under_thr))
# Out:
# 0

# %%
# Issue 4 to correct: some entries have salaries in unit 'year' that should be, after
# examination, in 'month' unit. We correct them, as we located them in the previous step,
# just use their offer_id.
# List of offers to fix
ids_to_fix = [4478, 3563]

# Change salary_unit from 'year' to 'month' for those offer_ids
df.loc[df["offer_id"].isin(ids_to_fix), "salary_unit"] = "month"

# %%
# To check
df.loc[df["offer_id"].isin(ids_to_fix), ["offer_id", "salary_min", "salary_max", "salary_unit"]]
# Out:
#       offer_id  salary_min  salary_max salary_unit
# 3561      3563      4200.0      6700.0       month
# 4476      4478      4000.0      8000.0       month

# %%
def convert_row_to_hour(row):
    min_sal = row["salary_min"]
    max_sal = row["salary_max"]
    unit_in = row["salary_unit"]      # 'year', nan, 'hour', 'month'
    hours   = row["hours_a_week"]     # take from the mapping defined above
    
    # If any of these are missing, keep NaNs
    if pd.isna(min_sal) or pd.isna(max_sal) or pd.isna(unit_in):
        return pd.Series(
            [np.nan, np.nan],
            index=["salary_min_hour", "salary_max_hour"]
        )

    # Use the salary conversion function (utilities.py)
    min_y, max_y = salary_conversion(min_sal, max_sal, unit_in, "hour", hours)
    return pd.Series(
        [min_y, max_y],
        index=["salary_min_hour", "salary_max_hour"]
    )

# %%
# Apply the function to create the new columns, and the average salary per hour
df[["salary_min_hour", "salary_max_hour"]] = df.apply(convert_row_to_hour, axis=1)
df["salary_avg_hour"] = df[["salary_min_hour", "salary_max_hour"]].mean(axis=1)

# %%
df.columns
# Out:
# Index(['offer_id', 'title', 'company_name', 'city', 'state_code',
#        'seniority_level', 'job_type', 'job_function', 'industry',
#        'description', 'salary_min', 'salary_max', 'salary_unit', 'salary',
#        'searched_position', 'searched_location', 'applications', 'nltk_lemmas',
#        'hours_a_week', 'salary_min_hour', 'salary_max_hour',
#        'salary_avg_hour'],
#       dtype='object')

# %%
print("\n====== Check NAs ======")
print(df.isna().sum().to_frame(name="NA_Counts"))
# Out:
# ====== Check NAs ======
#                    NA_Counts
# offer_id                   0
# title                      0
# company_name               0
# city                     408
# state_code                 0
# seniority_level            0
# job_type                   0
# job_function               5
# industry                   1
# description                0
# salary_min              3673
# salary_max              3673
# salary_unit                0
# salary                  3673
# searched_position          0
# searched_location          0
# applications               0
# nltk_lemmas                0
# hours_a_week               0
# salary_min_hour         3673
# salary_max_hour         3673
# salary_avg_hour         3673

# %%
# To save
file_path= "C:/Users/adeli/Documents 4-Q1/Web Analytics/Final Project GitHub/web-analytics-project-repo/Processed data/"

file_name= "linkedin_converted_salaries_hour_30emb.csv"
df.to_csv(file_path + file_name, index=False)
print(f"Data has been saved to file: {file_name}")
# df.to_csv("linkedin_converted_salaries_hour.csv", index=False)
# Out:
# Data has been saved to file: linkedin_converted_salaries_hour_30emb.csv

# %% [markdown]
# #### Legacy code

# %%
# Used to correct three entries that were outliers because they had salary_unit as day
# when the should have been year
ids_with_nan = [115, 1350, 6894] 
df.loc[df["offer_id"].isin(ids_with_nan), "salary_unit"] = "year"
