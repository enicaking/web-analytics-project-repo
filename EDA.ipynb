# %%
import pandas as pd

# %%
df = pd.read_csv("jobs_linkedin_parsed.csv")
df.head()
# Out:
#    offer_id                          title                company_name  \
# 0         0  Software Engineering Graduate  Hewlett Packard Enterprise
# 1         1              Software Engineer       Veracity Software Inc
# 2         2              Software Engineer                        Epic
# 3         3              Software Engineer                        Epic
# 4         4    Software Engineering Intern  Hewlett Packard Enterprise
#
#          city state_code   seniority_level   job_type  \
# 0   Roseville         CA    Not Applicable  Full-time
# 1  Sacramento         CA  Mid-Senior level  Full-time
# 2   Elk Grove         CA       Entry level  Full-time
# 3  Sacramento         CA       Entry level  Full-time
# 4   Roseville         CA    Not Applicable  Full-time
#
#                              job_function                       industry  \
# 0  Engineering and Information Technology  IT Services and IT Consulting
# ...
